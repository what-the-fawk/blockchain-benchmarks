# %%
# %pip install bayesian-optimization
# %pip install hebo
# %pip install GPyOpt
# %pip install ax-platform scikit-learn numpy pandas matplotlib
# %pip install pyGPGO
# %pip install torch
# %pip install antbo
# %pip install ax-platform botorch emukit dragonfly-opt gpyopt smac
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: bayesian-optimization in /home/admin1/.local/lib/python3.10/site-packages (2.0.3)
# Requirement already satisfied: numpy>=1.25 in /home/admin1/.local/lib/python3.10/site-packages (from bayesian-optimization) (1.26.4)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in /home/admin1/.local/lib/python3.10/site-packages (from bayesian-optimization) (0.4.6)
# Requirement already satisfied: scipy<2.0.0,>=1.0.0 in /home/admin1/.local/lib/python3.10/site-packages (from bayesian-optimization) (1.12.0)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.0.0 in /home/admin1/.local/lib/python3.10/site-packages (from bayesian-optimization) (1.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/admin1/.local/lib/python3.10/site-packages (from scikit-learn<2.0.0,>=1.0.0->bayesian-optimization) (1.3.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/admin1/.local/lib/python3.10/site-packages (from scikit-learn<2.0.0,>=1.0.0->bayesian-optimization) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: hebo in /home/admin1/.local/lib/python3.10/site-packages (0.3.6)
# Requirement already satisfied: catboost>=0.24.4 in /home/admin1/.local/lib/python3.10/site-packages (from hebo) (1.2.2)
# Requirement already satisfied: gpytorch>=1.4.0 in /home/admin1/.local/lib/python3.10/site-packages (from hebo) (1.14)
# Requirement already satisfied: pymoo==0.6.0 in /home/admin1/.local/lib/python3.10/site-packages (from hebo) (0.6.0)
# Requirement already satisfied: torch>=1.9.0 in /home/admin1/.local/lib/python3.10/site-packages (from hebo) (2.6.0)
# Requirement already satisfied: scikit-learn>=0.22 in /home/admin1/.local/lib/python3.10/site-packages (from hebo) (1.6.1)
# Requirement already satisfied: pandas>=1.0.1 in /home/admin1/.local/lib/python3.10/site-packages (from hebo) (2.0.3)
# Requirement already satisfied: disjoint-set in /home/admin1/.local/lib/python3.10/site-packages (from hebo) (0.8.0)
# Requirement already satisfied: GPy>=1.9.9 in /home/admin1/.local/lib/python3.10/site-packages (from hebo) (1.13.2)
# Collecting numpy<1.25,>=1.16
#   Using cached numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Requirement already satisfied: alive-progress in /home/admin1/.local/lib/python3.10/site-packages (from pymoo==0.6.0->hebo) (3.2.0)
# Requirement already satisfied: matplotlib>=3 in /home/admin1/.local/lib/python3.10/site-packages (from pymoo==0.6.0->hebo) (3.10.1)
# Requirement already satisfied: Deprecated in /home/admin1/.local/lib/python3.10/site-packages (from pymoo==0.6.0->hebo) (1.2.18)
# Requirement already satisfied: dill in /home/admin1/.local/lib/python3.10/site-packages (from pymoo==0.6.0->hebo) (0.3.9)
# Requirement already satisfied: scipy>=1.1 in /home/admin1/.local/lib/python3.10/site-packages (from pymoo==0.6.0->hebo) (1.12.0)
# Requirement already satisfied: autograd>=1.4 in /home/admin1/.local/lib/python3.10/site-packages (from pymoo==0.6.0->hebo) (1.7.0)
# Requirement already satisfied: cma==3.2.2 in /home/admin1/.local/lib/python3.10/site-packages (from pymoo==0.6.0->hebo) (3.2.2)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from catboost>=0.24.4->hebo) (1.16.0)
# Requirement already satisfied: graphviz in /home/admin1/.local/lib/python3.10/site-packages (from catboost>=0.24.4->hebo) (0.20.1)
# Requirement already satisfied: plotly in /home/admin1/.local/lib/python3.10/site-packages (from catboost>=0.24.4->hebo) (5.18.0)
# Requirement already satisfied: paramz>=0.9.6 in /home/admin1/.local/lib/python3.10/site-packages (from GPy>=1.9.9->hebo) (0.9.6)
# Requirement already satisfied: cython>=0.29 in /home/admin1/.local/lib/python3.10/site-packages (from GPy>=1.9.9->hebo) (3.0.12)
# Requirement already satisfied: jaxtyping in /home/admin1/.local/lib/python3.10/site-packages (from gpytorch>=1.4.0->hebo) (0.3.1)
# Requirement already satisfied: linear-operator>=0.6 in /home/admin1/.local/lib/python3.10/site-packages (from gpytorch>=1.4.0->hebo) (0.6)
# Requirement already satisfied: mpmath<=1.3,>=0.19 in /home/admin1/.local/lib/python3.10/site-packages (from gpytorch>=1.4.0->hebo) (1.3.0)
# Requirement already satisfied: tzdata>=2022.1 in /home/admin1/.local/lib/python3.10/site-packages (from pandas>=1.0.1->hebo) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/admin1/.local/lib/python3.10/site-packages (from pandas>=1.0.1->hebo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/admin1/.local/lib/python3.10/site-packages (from pandas>=1.0.1->hebo) (2023.3.post1)
# Requirement already satisfied: joblib>=1.2.0 in /home/admin1/.local/lib/python3.10/site-packages (from scikit-learn>=0.22->hebo) (1.3.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/admin1/.local/lib/python3.10/site-packages (from scikit-learn>=0.22->hebo) (3.2.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=1.9.0->hebo) (12.4.127)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=1.9.0->hebo) (12.4.5.8)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=1.9.0->hebo) (12.4.127)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=1.9.0->hebo) (0.6.2)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=1.9.0->hebo) (10.3.5.147)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=1.9.0->hebo) (4.13.1)
# Requirement already satisfied: networkx in /home/admin1/.local/lib/python3.10/site-packages (from torch>=1.9.0->hebo) (3.2.1)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=1.9.0->hebo) (12.3.1.170)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=1.9.0->hebo) (12.4.127)
# Requirement already satisfied: fsspec in /home/admin1/.local/lib/python3.10/site-packages (from torch>=1.9.0->hebo) (2025.3.2)
# Requirement already satisfied: jinja2 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=1.9.0->hebo) (3.1.2)
# Requirement already satisfied: sympy==1.13.1 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=1.9.0->hebo) (1.13.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=1.9.0->hebo) (12.4.127)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=1.9.0->hebo) (12.4.127)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->hebo) (3.13.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=1.9.0->hebo) (2.21.5)
# Requirement already satisfied: triton==3.2.0 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=1.9.0->hebo) (3.2.0)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=1.9.0->hebo) (11.2.1.3)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=1.9.0->hebo) (9.1.0.70)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=1.9.0->hebo) (11.6.1.9)
# Requirement already satisfied: cycler>=0.10 in /home/admin1/.local/lib/python3.10/site-packages (from matplotlib>=3->pymoo==0.6.0->hebo) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/admin1/.local/lib/python3.10/site-packages (from matplotlib>=3->pymoo==0.6.0->hebo) (1.2.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/admin1/.local/lib/python3.10/site-packages (from matplotlib>=3->pymoo==0.6.0->hebo) (1.4.5)
# Requirement already satisfied: pillow>=8 in /usr/lib/python3/dist-packages (from matplotlib>=3->pymoo==0.6.0->hebo) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/admin1/.local/lib/python3.10/site-packages (from matplotlib>=3->pymoo==0.6.0->hebo) (4.45.1)
# Requirement already satisfied: packaging>=20.0 in /home/admin1/.local/lib/python3.10/site-packages (from matplotlib>=3->pymoo==0.6.0->hebo) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3->pymoo==0.6.0->hebo) (2.4.7)
# Requirement already satisfied: decorator>=4.0.10 in /home/admin1/.local/lib/python3.10/site-packages (from paramz>=0.9.6->GPy>=1.9.9->hebo) (5.1.1)
# Requirement already satisfied: about-time==4.2.1 in /home/admin1/.local/lib/python3.10/site-packages (from alive-progress->pymoo==0.6.0->hebo) (4.2.1)
# Requirement already satisfied: grapheme==0.6.0 in /home/admin1/.local/lib/python3.10/site-packages (from alive-progress->pymoo==0.6.0->hebo) (0.6.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/admin1/.local/lib/python3.10/site-packages (from Deprecated->pymoo==0.6.0->hebo) (1.17.2)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /home/admin1/.local/lib/python3.10/site-packages (from jaxtyping->gpytorch>=1.4.0->hebo) (0.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/admin1/.local/lib/python3.10/site-packages (from jinja2->torch>=1.9.0->hebo) (2.1.3)
# Requirement already satisfied: tenacity>=6.2.0 in /home/admin1/.local/lib/python3.10/site-packages (from plotly->catboost>=0.24.4->hebo) (8.2.3)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pymc3 3.11.6 requires numpy<1.22.2,>=1.15.0, but you have numpy 1.24.4 which is incompatible.
# pymc3 3.11.6 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.12.0 which is incompatible.
# crosspredict 1.1.9 requires pytest==6.2.4, but you have pytest 8.3.4 which is incompatible.
# crosspredict 1.1.9 requires pytest-print==0.3.0, but you have pytest-print 1.1.0 which is incompatible.
# crosspredict 1.1.9 requires pyyaml==5.3, but you have pyyaml 5.4.1 which is incompatible.
# bayesian-optimization 2.0.3 requires numpy>=1.25, but you have numpy 1.24.4 which is incompatible.
# Successfully installed numpy-1.24.4
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: GPyOpt in /home/admin1/.local/lib/python3.10/site-packages (1.2.6)
# Requirement already satisfied: GPy>=1.8 in /home/admin1/.local/lib/python3.10/site-packages (from GPyOpt) (1.13.2)
# Requirement already satisfied: scipy>=0.16 in /home/admin1/.local/lib/python3.10/site-packages (from GPyOpt) (1.12.0)
# Requirement already satisfied: numpy>=1.7 in /home/admin1/.local/lib/python3.10/site-packages (from GPyOpt) (1.24.4)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from GPy>=1.8->GPyOpt) (1.16.0)
# Requirement already satisfied: paramz>=0.9.6 in /home/admin1/.local/lib/python3.10/site-packages (from GPy>=1.8->GPyOpt) (0.9.6)
# Requirement already satisfied: cython>=0.29 in /home/admin1/.local/lib/python3.10/site-packages (from GPy>=1.8->GPyOpt) (3.0.12)
# Requirement already satisfied: decorator>=4.0.10 in /home/admin1/.local/lib/python3.10/site-packages (from paramz>=0.9.6->GPy>=1.8->GPyOpt) (5.1.1)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ax-platform in /home/admin1/.local/lib/python3.10/site-packages (0.5.0)
# Requirement already satisfied: scikit-learn in /home/admin1/.local/lib/python3.10/site-packages (1.6.1)
# Requirement already satisfied: numpy in /home/admin1/.local/lib/python3.10/site-packages (1.24.4)
# Requirement already satisfied: pandas in /home/admin1/.local/lib/python3.10/site-packages (2.0.3)
# Requirement already satisfied: matplotlib in /home/admin1/.local/lib/python3.10/site-packages (3.10.1)
# Requirement already satisfied: ipywidgets in /home/admin1/.local/lib/python3.10/site-packages (from ax-platform) (8.1.5)
# Requirement already satisfied: plotly>=5.12.0 in /home/admin1/.local/lib/python3.10/site-packages (from ax-platform) (5.18.0)
# Requirement already satisfied: sympy in /home/admin1/.local/lib/python3.10/site-packages (from ax-platform) (1.13.1)
# Requirement already satisfied: scipy in /home/admin1/.local/lib/python3.10/site-packages (from ax-platform) (1.12.0)
# Requirement already satisfied: botorch==0.13.0 in /home/admin1/.local/lib/python3.10/site-packages (from ax-platform) (0.13.0)
# Requirement already satisfied: pyre-extensions in /home/admin1/.local/lib/python3.10/site-packages (from ax-platform) (0.0.32)
# Requirement already satisfied: jinja2 in /home/admin1/.local/lib/python3.10/site-packages (from ax-platform) (3.1.2)
# Requirement already satisfied: typing_extensions in /home/admin1/.local/lib/python3.10/site-packages (from botorch==0.13.0->ax-platform) (4.13.1)
# Requirement already satisfied: linear_operator==0.6 in /home/admin1/.local/lib/python3.10/site-packages (from botorch==0.13.0->ax-platform) (0.6)
# Requirement already satisfied: threadpoolctl in /home/admin1/.local/lib/python3.10/site-packages (from botorch==0.13.0->ax-platform) (3.2.0)
# Requirement already satisfied: torch>=2.0.1 in /home/admin1/.local/lib/python3.10/site-packages (from botorch==0.13.0->ax-platform) (2.6.0)
# Requirement already satisfied: pyro-ppl>=1.8.4 in /home/admin1/.local/lib/python3.10/site-packages (from botorch==0.13.0->ax-platform) (1.9.1)
# Requirement already satisfied: gpytorch==1.14 in /home/admin1/.local/lib/python3.10/site-packages (from botorch==0.13.0->ax-platform) (1.14)
# Requirement already satisfied: multipledispatch in /home/admin1/.local/lib/python3.10/site-packages (from botorch==0.13.0->ax-platform) (1.0.0)
# Requirement already satisfied: mpmath<=1.3,>=0.19 in /home/admin1/.local/lib/python3.10/site-packages (from gpytorch==1.14->botorch==0.13.0->ax-platform) (1.3.0)
# Requirement already satisfied: jaxtyping in /home/admin1/.local/lib/python3.10/site-packages (from gpytorch==1.14->botorch==0.13.0->ax-platform) (0.3.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/admin1/.local/lib/python3.10/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/admin1/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/admin1/.local/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/admin1/.local/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/admin1/.local/lib/python3.10/site-packages (from matplotlib) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/admin1/.local/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: contourpy>=1.0.1 in /home/admin1/.local/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/admin1/.local/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pillow>=8 in /usr/lib/python3/dist-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in /home/admin1/.local/lib/python3.10/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: tenacity>=6.2.0 in /home/admin1/.local/lib/python3.10/site-packages (from plotly>=5.12.0->ax-platform) (8.2.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: comm>=0.1.3 in /home/admin1/.local/lib/python3.10/site-packages (from ipywidgets->ax-platform) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /home/admin1/.local/lib/python3.10/site-packages (from ipywidgets->ax-platform) (4.0.13)
# Requirement already satisfied: traitlets>=4.3.1 in /home/admin1/.local/lib/python3.10/site-packages (from ipywidgets->ax-platform) (5.13.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /home/admin1/.local/lib/python3.10/site-packages (from ipywidgets->ax-platform) (3.0.13)
# Requirement already satisfied: ipython>=6.1.0 in /home/admin1/.local/lib/python3.10/site-packages (from ipywidgets->ax-platform) (8.18.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/admin1/.local/lib/python3.10/site-packages (from jinja2->ax-platform) (2.1.3)
# Requirement already satisfied: typing-inspect in /home/admin1/.local/lib/python3.10/site-packages (from pyre-extensions->ax-platform) (0.9.0)
# Requirement already satisfied: decorator in /home/admin1/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/admin1/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (3.0.41)
# Requirement already satisfied: matplotlib-inline in /home/admin1/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (4.8.0)
# Requirement already satisfied: pygments>=2.4.0 in /home/admin1/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (2.17.2)
# Requirement already satisfied: exceptiongroup in /home/admin1/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (1.1.3)
# Requirement already satisfied: stack-data in /home/admin1/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (0.6.3)
# Requirement already satisfied: jedi>=0.16 in /home/admin1/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (0.19.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/admin1/.local/lib/python3.10/site-packages (from pyro-ppl>=1.8.4->botorch==0.13.0->ax-platform) (3.4.0)
# Requirement already satisfied: pyro-api>=0.1.1 in /home/admin1/.local/lib/python3.10/site-packages (from pyro-ppl>=1.8.4->botorch==0.13.0->ax-platform) (0.1.2)
# Requirement already satisfied: tqdm>=4.36 in /home/admin1/.local/lib/python3.10/site-packages (from pyro-ppl>=1.8.4->botorch==0.13.0->ax-platform) (4.66.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch==0.13.0->ax-platform) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch==0.13.0->ax-platform) (3.2.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch==0.13.0->ax-platform) (12.4.5.8)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch==0.13.0->ax-platform) (12.4.127)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch==0.13.0->ax-platform) (10.3.5.147)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->botorch==0.13.0->ax-platform) (3.13.1)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch==0.13.0->ax-platform) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch==0.13.0->ax-platform) (0.6.2)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch==0.13.0->ax-platform) (9.1.0.70)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch==0.13.0->ax-platform) (12.4.127)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch==0.13.0->ax-platform) (12.4.127)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch==0.13.0->ax-platform) (11.2.1.3)
# Requirement already satisfied: networkx in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch==0.13.0->ax-platform) (3.2.1)
# Requirement already satisfied: fsspec in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch==0.13.0->ax-platform) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch==0.13.0->ax-platform) (12.4.127)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch==0.13.0->ax-platform) (11.6.1.9)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch==0.13.0->ax-platform) (2.21.5)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/admin1/.local/lib/python3.10/site-packages (from typing-inspect->pyre-extensions->ax-platform) (1.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/admin1/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ax-platform) (0.8.3)
# Requirement already satisfied: wcwidth in /home/admin1/.local/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets->ax-platform) (0.2.12)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /home/admin1/.local/lib/python3.10/site-packages (from jaxtyping->gpytorch==1.14->botorch==0.13.0->ax-platform) (0.1.4)
# Requirement already satisfied: executing>=1.2.0 in /home/admin1/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ax-platform) (2.0.1)
# Requirement already satisfied: pure-eval in /home/admin1/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ax-platform) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /home/admin1/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ax-platform) (2.4.1)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyGPGO in /home/admin1/.local/lib/python3.10/site-packages (0.5.1)
# Requirement already satisfied: scipy in /home/admin1/.local/lib/python3.10/site-packages (from pyGPGO) (1.12.0)
# Requirement already satisfied: numpy in /home/admin1/.local/lib/python3.10/site-packages (from pyGPGO) (1.24.4)
# Requirement already satisfied: scikit-learn in /home/admin1/.local/lib/python3.10/site-packages (from pyGPGO) (1.6.1)
# Requirement already satisfied: joblib in /home/admin1/.local/lib/python3.10/site-packages (from pyGPGO) (1.3.2)
# Requirement already satisfied: mkl in /home/admin1/.local/lib/python3.10/site-packages (from pyGPGO) (2025.1.0)
# Requirement already satisfied: pyMC3 in /home/admin1/.local/lib/python3.10/site-packages (from pyGPGO) (3.11.6)
# Requirement already satisfied: Theano-PyMC in /home/admin1/.local/lib/python3.10/site-packages (from pyGPGO) (1.1.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /home/admin1/.local/lib/python3.10/site-packages (from mkl->pyGPGO) (2025.1.0)
# Requirement already satisfied: tbb==2022.* in /home/admin1/.local/lib/python3.10/site-packages (from mkl->pyGPGO) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /home/admin1/.local/lib/python3.10/site-packages (from tbb==2022.*->mkl->pyGPGO) (1.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /home/admin1/.local/lib/python3.10/site-packages (from pyMC3->pyGPGO) (4.13.1)
# Requirement already satisfied: fastprogress>=0.2.0 in /home/admin1/.local/lib/python3.10/site-packages (from pyMC3->pyGPGO) (1.0.3)
# Requirement already satisfied: arviz>=0.11.0 in /home/admin1/.local/lib/python3.10/site-packages (from pyMC3->pyGPGO) (0.12.1)
# Collecting numpy
#   Using cached numpy-1.22.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# Requirement already satisfied: semver>=2.13.0 in /home/admin1/.local/lib/python3.10/site-packages (from pyMC3->pyGPGO) (3.0.4)
# Requirement already satisfied: pandas>=0.24.0 in /home/admin1/.local/lib/python3.10/site-packages (from pyMC3->pyGPGO) (2.0.3)
# Requirement already satisfied: deprecat in /home/admin1/.local/lib/python3.10/site-packages (from pyMC3->pyGPGO) (2.1.3)
# Requirement already satisfied: patsy>=0.5.1 in /home/admin1/.local/lib/python3.10/site-packages (from pyMC3->pyGPGO) (0.5.6)
# Requirement already satisfied: cachetools>=4.2.1 in /home/admin1/.local/lib/python3.10/site-packages (from pyMC3->pyGPGO) (5.5.2)
# Collecting scipy
#   Using cached scipy-1.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.9 MB)
# Requirement already satisfied: dill in /home/admin1/.local/lib/python3.10/site-packages (from pyMC3->pyGPGO) (0.3.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from Theano-PyMC->pyGPGO) (3.13.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/admin1/.local/lib/python3.10/site-packages (from scikit-learn->pyGPGO) (3.2.0)
# Requirement already satisfied: setuptools>=38.4 in /usr/lib/python3/dist-packages (from arviz>=0.11.0->pyMC3->pyGPGO) (59.6.0)
# Requirement already satisfied: matplotlib>=3.0 in /home/admin1/.local/lib/python3.10/site-packages (from arviz>=0.11.0->pyMC3->pyGPGO) (3.10.1)
# Requirement already satisfied: xarray-einstats>=0.2 in /home/admin1/.local/lib/python3.10/site-packages (from arviz>=0.11.0->pyMC3->pyGPGO) (0.6.0)
# Requirement already satisfied: netcdf4 in /home/admin1/.local/lib/python3.10/site-packages (from arviz>=0.11.0->pyMC3->pyGPGO) (1.7.2)
# Requirement already satisfied: packaging in /home/admin1/.local/lib/python3.10/site-packages (from arviz>=0.11.0->pyMC3->pyGPGO) (24.2)
# Requirement already satisfied: xarray>=0.16.1 in /home/admin1/.local/lib/python3.10/site-packages (from arviz>=0.11.0->pyMC3->pyGPGO) (2023.12.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2025.1.0 in /home/admin1/.local/lib/python3.10/site-packages (from intel-openmp<2026,>=2024->mkl->pyGPGO) (2025.1.0)
# Requirement already satisfied: umf==0.10.* in /home/admin1/.local/lib/python3.10/site-packages (from intel-cmplr-lib-ur==2025.1.0->intel-openmp<2026,>=2024->mkl->pyGPGO) (0.10.0)
# Requirement already satisfied: pytz>=2020.1 in /home/admin1/.local/lib/python3.10/site-packages (from pandas>=0.24.0->pyMC3->pyGPGO) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/admin1/.local/lib/python3.10/site-packages (from pandas>=0.24.0->pyMC3->pyGPGO) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/admin1/.local/lib/python3.10/site-packages (from pandas>=0.24.0->pyMC3->pyGPGO) (2.8.2)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from patsy>=0.5.1->pyMC3->pyGPGO) (1.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/admin1/.local/lib/python3.10/site-packages (from deprecat->pyMC3->pyGPGO) (1.17.2)
# Collecting matplotlib>=3.0
#   Using cached matplotlib-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#   Using cached matplotlib-3.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#   Using cached matplotlib-3.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#   Using cached matplotlib-3.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#   Using cached matplotlib-3.9.1.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#   Using cached matplotlib-3.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#   Using cached matplotlib-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
# Requirement already satisfied: pillow>=8 in /usr/lib/python3/dist-packages (from matplotlib>=3.0->arviz>=0.11.0->pyMC3->pyGPGO) (9.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/admin1/.local/lib/python3.10/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pyMC3->pyGPGO) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/admin1/.local/lib/python3.10/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pyMC3->pyGPGO) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.0->arviz>=0.11.0->pyMC3->pyGPGO) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/admin1/.local/lib/python3.10/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pyMC3->pyGPGO) (1.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in /home/admin1/.local/lib/python3.10/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pyMC3->pyGPGO) (4.45.1)
# Requirement already satisfied: certifi in /home/admin1/.local/lib/python3.10/site-packages (from netcdf4->arviz>=0.11.0->pyMC3->pyGPGO) (2023.11.17)
# Requirement already satisfied: cftime in /home/admin1/.local/lib/python3.10/site-packages (from netcdf4->arviz>=0.11.0->pyMC3->pyGPGO) (1.6.4.post1)
# Installing collected packages: numpy, scipy, matplotlib
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.12.0
#     Uninstalling scipy-1.12.0:
#       Successfully uninstalled scipy-1.12.0
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.1
#     Uninstalling matplotlib-3.10.1:
#       Successfully uninstalled matplotlib-3.10.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# statsmodels 0.14.3 requires numpy<3,>=1.22.3, but you have numpy 1.22.1 which is incompatible.
# statsmodels 0.14.3 requires scipy!=1.9.2,>=1.8, but you have scipy 1.7.3 which is incompatible.
# smac 2.1.0 requires numpy>=1.23.3, but you have numpy 1.22.1 which is incompatible.
# smac 2.1.0 requires scipy>=1.9.2, but you have scipy 1.7.3 which is incompatible.
# salib 1.5.1 requires scipy>=1.9.3, but you have scipy 1.7.3 which is incompatible.
# emukit 0.4.11 requires matplotlib>=3.9, but you have matplotlib 3.8.4 which is incompatible.
# emukit 0.4.11 requires numpy>=1.23, but you have numpy 1.22.1 which is incompatible.
# crosspredict 1.1.9 requires pytest==6.2.4, but you have pytest 8.3.4 which is incompatible.
# crosspredict 1.1.9 requires pytest-print==0.3.0, but you have pytest-print 1.1.0 which is incompatible.
# crosspredict 1.1.9 requires pyyaml==5.3, but you have pyyaml 5.4.1 which is incompatible.
# bayesian-optimization 2.0.3 requires numpy>=1.25, but you have numpy 1.22.1 which is incompatible.
# Successfully installed matplotlib-3.8.4 numpy-1.22.1 scipy-1.7.3
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /home/admin1/.local/lib/python3.10/site-packages (2.6.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/admin1/.local/lib/python3.10/site-packages (from torch) (4.13.1)
# Requirement already satisfied: fsspec in /home/admin1/.local/lib/python3.10/site-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/admin1/.local/lib/python3.10/site-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/admin1/.local/lib/python3.10/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/admin1/.local/lib/python3.10/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/admin1/.local/lib/python3.10/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: sympy==1.13.1 in /home/admin1/.local/lib/python3.10/site-packages (from torch) (1.13.1)
# Requirement already satisfied: triton==3.2.0 in /home/admin1/.local/lib/python3.10/site-packages (from torch) (3.2.0)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/admin1/.local/lib/python3.10/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/admin1/.local/lib/python3.10/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/admin1/.local/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/admin1/.local/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/admin1/.local/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/admin1/.local/lib/python3.10/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/admin1/.local/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: jinja2 in /home/admin1/.local/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: networkx in /home/admin1/.local/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/admin1/.local/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/admin1/.local/lib/python3.10/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/admin1/.local/lib/python3.10/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/admin1/.local/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement antbo (from versions: none)
# ERROR: No matching distribution found for antbo
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ax-platform in /home/admin1/.local/lib/python3.10/site-packages (0.5.0)
# Requirement already satisfied: botorch in /home/admin1/.local/lib/python3.10/site-packages (0.13.0)
# Requirement already satisfied: emukit in /home/admin1/.local/lib/python3.10/site-packages (0.4.11)
# Requirement already satisfied: dragonfly-opt in /home/admin1/.local/lib/python3.10/site-packages (0.1.7)
# Requirement already satisfied: gpyopt in /home/admin1/.local/lib/python3.10/site-packages (1.2.6)
# Requirement already satisfied: smac in /home/admin1/.local/lib/python3.10/site-packages (2.1.0)
# Requirement already satisfied: pyre-extensions in /home/admin1/.local/lib/python3.10/site-packages (from ax-platform) (0.0.32)
# Requirement already satisfied: ipywidgets in /home/admin1/.local/lib/python3.10/site-packages (from ax-platform) (8.1.5)
# Requirement already satisfied: scikit-learn in /home/admin1/.local/lib/python3.10/site-packages (from ax-platform) (1.6.1)
# Requirement already satisfied: scipy in /home/admin1/.local/lib/python3.10/site-packages (from ax-platform) (1.7.3)
# Requirement already satisfied: sympy in /home/admin1/.local/lib/python3.10/site-packages (from ax-platform) (1.13.1)
# Requirement already satisfied: plotly>=5.12.0 in /home/admin1/.local/lib/python3.10/site-packages (from ax-platform) (5.18.0)
# Requirement already satisfied: jinja2 in /home/admin1/.local/lib/python3.10/site-packages (from ax-platform) (3.1.2)
# Requirement already satisfied: pandas in /home/admin1/.local/lib/python3.10/site-packages (from ax-platform) (2.0.3)
# Requirement already satisfied: linear_operator==0.6 in /home/admin1/.local/lib/python3.10/site-packages (from botorch) (0.6)
# Requirement already satisfied: multipledispatch in /home/admin1/.local/lib/python3.10/site-packages (from botorch) (1.0.0)
# Requirement already satisfied: pyro-ppl>=1.8.4 in /home/admin1/.local/lib/python3.10/site-packages (from botorch) (1.9.1)
# Requirement already satisfied: threadpoolctl in /home/admin1/.local/lib/python3.10/site-packages (from botorch) (3.2.0)
# Requirement already satisfied: gpytorch==1.14 in /home/admin1/.local/lib/python3.10/site-packages (from botorch) (1.14)
# Requirement already satisfied: typing_extensions in /home/admin1/.local/lib/python3.10/site-packages (from botorch) (4.13.1)
# Requirement already satisfied: torch>=2.0.1 in /home/admin1/.local/lib/python3.10/site-packages (from botorch) (2.6.0)
# Requirement already satisfied: jaxtyping in /home/admin1/.local/lib/python3.10/site-packages (from gpytorch==1.14->botorch) (0.3.1)
# Requirement already satisfied: mpmath<=1.3,>=0.19 in /home/admin1/.local/lib/python3.10/site-packages (from gpytorch==1.14->botorch) (1.3.0)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/lib/python3/dist-packages (from emukit) (59.6.0)
# Collecting numpy>=1.23
#   Using cached numpy-2.2.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
# Collecting matplotlib>=3.9
#   Using cached matplotlib-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
# Requirement already satisfied: emcee>=2.2.1 in /home/admin1/.local/lib/python3.10/site-packages (from emukit) (3.1.6)
# Requirement already satisfied: GPy>=1.13.0 in /home/admin1/.local/lib/python3.10/site-packages (from emukit) (1.13.2)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from dragonfly-opt) (1.16.0)
# Requirement already satisfied: future in /usr/lib/python3/dist-packages (from dragonfly-opt) (0.18.2)
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (from smac) (5.4.1)
# Requirement already satisfied: pynisher>=1.0.0 in /home/admin1/.local/lib/python3.10/site-packages (from smac) (1.0.10)
# Requirement already satisfied: pyrfr>=0.9.0 in /home/admin1/.local/lib/python3.10/site-packages (from smac) (0.9.0)
# Collecting scipy
#   Using cached scipy-1.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.6 MB)
# Requirement already satisfied: psutil in /home/admin1/.local/lib/python3.10/site-packages (from smac) (5.9.6)
# Requirement already satisfied: dask[distributed] in /home/admin1/.local/lib/python3.10/site-packages (from smac) (2025.3.0)
# Requirement already satisfied: joblib in /home/admin1/.local/lib/python3.10/site-packages (from smac) (1.3.2)
# Requirement already satisfied: regex in /home/admin1/.local/lib/python3.10/site-packages (from smac) (2024.11.6)
# Requirement already satisfied: dask-jobqueue in /home/admin1/.local/lib/python3.10/site-packages (from smac) (0.9.0)
# Requirement already satisfied: ConfigSpace>=0.6.1 in /home/admin1/.local/lib/python3.10/site-packages (from smac) (0.7.1)
# Requirement already satisfied: pyparsing in /usr/lib/python3/dist-packages (from ConfigSpace>=0.6.1->smac) (2.4.7)
# Requirement already satisfied: more-itertools in /usr/lib/python3/dist-packages (from ConfigSpace>=0.6.1->smac) (8.10.0)
#   Using cached scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.4 MB)
# Requirement already satisfied: paramz>=0.9.6 in /home/admin1/.local/lib/python3.10/site-packages (from GPy>=1.13.0->emukit) (0.9.6)
# Requirement already satisfied: cython>=0.29 in /home/admin1/.local/lib/python3.10/site-packages (from GPy>=1.13.0->emukit) (3.0.12)
# Collecting numpy>=1.23
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Requirement already satisfied: cycler>=0.10 in /home/admin1/.local/lib/python3.10/site-packages (from matplotlib>=3.9->emukit) (0.12.1)
# Requirement already satisfied: pillow>=8 in /usr/lib/python3/dist-packages (from matplotlib>=3.9->emukit) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/admin1/.local/lib/python3.10/site-packages (from matplotlib>=3.9->emukit) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/admin1/.local/lib/python3.10/site-packages (from matplotlib>=3.9->emukit) (1.2.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/admin1/.local/lib/python3.10/site-packages (from matplotlib>=3.9->emukit) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/admin1/.local/lib/python3.10/site-packages (from matplotlib>=3.9->emukit) (24.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/admin1/.local/lib/python3.10/site-packages (from matplotlib>=3.9->emukit) (4.45.1)
# Requirement already satisfied: tenacity>=6.2.0 in /home/admin1/.local/lib/python3.10/site-packages (from plotly>=5.12.0->ax-platform) (8.2.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/admin1/.local/lib/python3.10/site-packages (from pyro-ppl>=1.8.4->botorch) (3.4.0)
# Requirement already satisfied: pyro-api>=0.1.1 in /home/admin1/.local/lib/python3.10/site-packages (from pyro-ppl>=1.8.4->botorch) (0.1.2)
# Requirement already satisfied: tqdm>=4.36 in /home/admin1/.local/lib/python3.10/site-packages (from pyro-ppl>=1.8.4->botorch) (4.66.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch) (12.4.127)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch) (0.6.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch) (12.3.1.170)
# Requirement already satisfied: networkx in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch) (3.2.1)
# Requirement already satisfied: fsspec in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch) (2025.3.2)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch) (10.3.5.147)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch) (3.2.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch) (12.4.127)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch) (11.2.1.3)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch) (12.4.5.8)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch) (12.4.127)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->botorch) (3.13.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/admin1/.local/lib/python3.10/site-packages (from torch>=2.0.1->botorch) (2.21.5)
# Requirement already satisfied: distributed>=2022.02.0 in /home/admin1/.local/lib/python3.10/site-packages (from dask-jobqueue->smac) (2025.3.0)
# Requirement already satisfied: toolz>=0.10.0 in /home/admin1/.local/lib/python3.10/site-packages (from dask[distributed]->smac) (1.0.0)
# Requirement already satisfied: cloudpickle>=3.0.0 in /home/admin1/.local/lib/python3.10/site-packages (from dask[distributed]->smac) (3.0.0)
# Requirement already satisfied: partd>=1.4.0 in /home/admin1/.local/lib/python3.10/site-packages (from dask[distributed]->smac) (1.4.2)
# Requirement already satisfied: click>=8.1 in /home/admin1/.local/lib/python3.10/site-packages (from dask[distributed]->smac) (8.1.7)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /home/admin1/.local/lib/python3.10/site-packages (from dask[distributed]->smac) (8.6.1)
# Requirement already satisfied: tornado>=6.2.0 in /home/admin1/.local/lib/python3.10/site-packages (from distributed>=2022.02.0->dask-jobqueue->smac) (6.3.3)
# Requirement already satisfied: urllib3>=1.26.5 in /usr/lib/python3/dist-packages (from distributed>=2022.02.0->dask-jobqueue->smac) (1.26.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /home/admin1/.local/lib/python3.10/site-packages (from distributed>=2022.02.0->dask-jobqueue->smac) (2.4.0)
# Requirement already satisfied: msgpack>=1.0.2 in /home/admin1/.local/lib/python3.10/site-packages (from distributed>=2022.02.0->dask-jobqueue->smac) (1.1.0)
# Requirement already satisfied: zict>=3.0.0 in /home/admin1/.local/lib/python3.10/site-packages (from distributed>=2022.02.0->dask-jobqueue->smac) (3.0.0)
# Requirement already satisfied: tblib>=1.6.0 in /home/admin1/.local/lib/python3.10/site-packages (from distributed>=2022.02.0->dask-jobqueue->smac) (3.1.0)
# Requirement already satisfied: locket>=1.0.0 in /home/admin1/.local/lib/python3.10/site-packages (from distributed>=2022.02.0->dask-jobqueue->smac) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/admin1/.local/lib/python3.10/site-packages (from jinja2->ax-platform) (2.1.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /home/admin1/.local/lib/python3.10/site-packages (from ipywidgets->ax-platform) (4.0.13)
# Requirement already satisfied: traitlets>=4.3.1 in /home/admin1/.local/lib/python3.10/site-packages (from ipywidgets->ax-platform) (5.13.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /home/admin1/.local/lib/python3.10/site-packages (from ipywidgets->ax-platform) (3.0.13)
# Requirement already satisfied: comm>=0.1.3 in /home/admin1/.local/lib/python3.10/site-packages (from ipywidgets->ax-platform) (0.2.0)
# Requirement already satisfied: ipython>=6.1.0 in /home/admin1/.local/lib/python3.10/site-packages (from ipywidgets->ax-platform) (8.18.0)
# Requirement already satisfied: pytz>=2020.1 in /home/admin1/.local/lib/python3.10/site-packages (from pandas->ax-platform) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/admin1/.local/lib/python3.10/site-packages (from pandas->ax-platform) (2023.3)
# Requirement already satisfied: typing-inspect in /home/admin1/.local/lib/python3.10/site-packages (from pyre-extensions->ax-platform) (0.9.0)
# Requirement already satisfied: zipp>=3.20 in /home/admin1/.local/lib/python3.10/site-packages (from importlib_metadata>=4.13.0->dask[distributed]->smac) (3.21.0)
# Requirement already satisfied: jedi>=0.16 in /home/admin1/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (0.19.1)
# Requirement already satisfied: decorator in /home/admin1/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /home/admin1/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (2.17.2)
# Requirement already satisfied: exceptiongroup in /home/admin1/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (1.1.3)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (4.8.0)
# Requirement already satisfied: stack-data in /home/admin1/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (0.6.3)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/admin1/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (3.0.41)
# Requirement already satisfied: matplotlib-inline in /home/admin1/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (0.1.6)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /home/admin1/.local/lib/python3.10/site-packages (from jaxtyping->gpytorch==1.14->botorch) (0.1.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/admin1/.local/lib/python3.10/site-packages (from typing-inspect->pyre-extensions->ax-platform) (1.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/admin1/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ax-platform) (0.8.3)
# Requirement already satisfied: wcwidth in /home/admin1/.local/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets->ax-platform) (0.2.12)
# Requirement already satisfied: executing>=1.2.0 in /home/admin1/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ax-platform) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/admin1/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ax-platform) (2.4.1)
# Requirement already satisfied: pure-eval in /home/admin1/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ax-platform) (0.2.2)
# Installing collected packages: numpy, scipy, matplotlib
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.1
#     Uninstalling numpy-1.22.1:
#       Successfully uninstalled numpy-1.22.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.4
#     Uninstalling matplotlib-3.8.4:
#       Successfully uninstalled matplotlib-3.8.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pymc3 3.11.6 requires numpy<1.22.2,>=1.15.0, but you have numpy 1.26.4 which is incompatible.
# pymc3 3.11.6 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.12.0 which is incompatible.
# numba 0.58.0 requires numpy<1.26,>=1.21, but you have numpy 1.26.4 which is incompatible.
# hebo 0.3.6 requires numpy<1.25,>=1.16, but you have numpy 1.26.4 which is incompatible.
# crosspredict 1.1.9 requires pytest==6.2.4, but you have pytest 8.3.4 which is incompatible.
# crosspredict 1.1.9 requires pytest-print==0.3.0, but you have pytest-print 1.1.0 which is incompatible.
# crosspredict 1.1.9 requires pyyaml==5.3, but you have pyyaml 5.4.1 which is incompatible.
# Successfully installed matplotlib-3.10.1 numpy-1.26.4 scipy-1.12.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from hebo.design_space.design_space import DesignSpace
from hebo.optimizers.hebo import HEBO
from line_profiler import LineProfiler

profiler = LineProfiler()

def example_bo():
    # Define design space with controllable and contextual parameters
    config = [
        {'name': 'x', 'type': 'num', 'lb': 0, 'ub': 10},  # Controllable
        {'name': 'context', 'type': 'num', 'lb': 5, 'ub': 15},  # Uncontrollable (context)
    ]
    space = DesignSpace().parse(config)

    # Initialize HEBO with fixed context
    opt = HEBO(space, model_name='gp', rand_sample=4)

    # Optimization loop (context fixed during run)
    fixed_context = 10.0  # Set uncontrollable variable
    for _ in range(20):
        rec = opt.suggest(n_suggestions=1, fix_input={'context': fixed_context})
        y = -((rec['x'] - 5)**2) + 0.1 * fixed_context  # Example objective
        opt.observe(rec, y.array)

    print(opt.best_y)

profiler.add_function(example_bo)
profiler.enable()
example_bo()
profiler.disable()

profiler.print_stats()
# Out:
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, give up fitting GP
# jitter = 1e-07
# jitter = 1e-06
# ...
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# jitter = 1e-07
# jitter = 1e-06
# jitter = 9.999999999999999e-06
# jitter = 9.999999999999999e-05
# jitter = 0.001
# jitter = 0.01
# jitter = 0.1
# jitter = 1.0
# jitter = 10.0
# jitter is too large, output random predictions
# -23.986164567907448
# Timer unit: 1e-09 s
#
# Total time: 124.729 s
# File: /tmp/ipykernel_11236/623481825.py
# Function: example_bo at line 7
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      7                                           def example_bo():
#      8                                               # Define design space with controllable and contextual parameters
#      9         1       1397.0   1397.0      0.0      config = [
#     10         1       1956.0   1956.0      0.0          {'name': 'x', 'type': 'num', 'lb': 0, 'ub': 10},  # Controllable
#     11         1       1397.0   1397.0      0.0          {'name': 'context', 'type': 'num', 'lb': 5, 'ub': 15},  # Uncontrollable (context)
#     12                                               ]
#     13         1      23397.0  23397.0      0.0      space = DesignSpace().parse(config)
#     14
#     15                                               # Initialize HEBO with fixed context
#     16         1   13344667.0    1e+07      0.0      opt = HEBO(space, model_name='gp', rand_sample=4)
#     17
#     18                                               # Optimization loop (context fixed during run)
#     19         1       1816.0   1816.0      0.0      fixed_context = 10.0  # Set uncontrollable variable
#     20        21      41769.0   1989.0      0.0      for _ in range(20):
#     21        20        1e+11    6e+09    100.0          rec = opt.suggest(n_suggestions=1, fix_input={'context': fixed_context})
#     22        20   10648549.0 532427.4      0.0          y = -((rec['x'] - 5)**2) + 0.1 * fixed_context  # Example objective
#     23        20   18524798.0 926239.9      0.0          opt.observe(rec, y.array)
#     24
#     25         1      31988.0  31988.0      0.0      print(opt.best_y)

# %%
profiler.print_stats()
# Out:
# Timer unit: 1e-09 s
#
# Total time: 124.729 s
# File: /tmp/ipykernel_11236/623481825.py
# Function: example_bo at line 7
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      7                                           def example_bo():
#      8                                               # Define design space with controllable and contextual parameters
#      9         1       1397.0   1397.0      0.0      config = [
#     10         1       1956.0   1956.0      0.0          {'name': 'x', 'type': 'num', 'lb': 0, 'ub': 10},  # Controllable
#     11         1       1397.0   1397.0      0.0          {'name': 'context', 'type': 'num', 'lb': 5, 'ub': 15},  # Uncontrollable (context)
#     12                                               ]
#     13         1      23397.0  23397.0      0.0      space = DesignSpace().parse(config)
#     14
#     15                                               # Initialize HEBO with fixed context
#     16         1   13344667.0    1e+07      0.0      opt = HEBO(space, model_name='gp', rand_sample=4)
#     17
#     18                                               # Optimization loop (context fixed during run)
#     19         1       1816.0   1816.0      0.0      fixed_context = 10.0  # Set uncontrollable variable
#     20        21      41769.0   1989.0      0.0      for _ in range(20):
#     21        20        1e+11    6e+09    100.0          rec = opt.suggest(n_suggestions=1, fix_input={'context': fixed_context})
#     22        20   10648549.0 532427.4      0.0          y = -((rec['x'] - 5)**2) + 0.1 * fixed_context  # Example objective
#     23        20   18524798.0 926239.9      0.0          opt.observe(rec, y.array)
#     24
#     25         1      31988.0  31988.0      0.0      print(opt.best_y)

# %%
import GPyOpt
import numpy as np

# Define the objective: f(c, x) = - (x - c)^2 + 1.
def f(X):
    c = X[:, 0]
    x = X[:, 1]
    print("objective")
    return (- (x - c)**2 + 1.0).reshape(-1, 1)

# Define the search domain.
domain = [
    {'name': 'c', 'type': 'continuous', 'domain': (0, 1)},
    {'name': 'x', 'type': 'continuous', 'domain': (0, 1)}
]

# Lock the uncontrollable parameter "c" to 0.7.
fixed_features = {'x': 0.7}  # Index 0 corresponds to "c"

# Create the Bayesian optimization object.
opt = GPyOpt.methods.BayesianOptimization(
    f=f,
    domain=domain,
    acquisition_type='EI',
    maximize=True,
    num_cores=4
)

# Run sequential optimization (each iteration evaluates one new point).
opt.run_optimization(max_iter=20, context=fixed_features)
best_index = opt.Y.argmax()
print("GPyOpt best configuration:", opt.X[best_index])
print("GPyOpt best objective value:", opt.Y[best_index])
# Out:
# objective
# objective
# objective
# objective
# objective
# objective
# objective
# objective
# objective
# objective
# objective
# objective
# objective
# objective
# objective
# objective
# objective
# objective
# objective
# objective
# objective
# objective
# objective
# objective
# objective
# GPyOpt best configuration: [0.09646287 0.96135899]
# GPyOpt best objective value: [-0.2519547]

# %%
import numpy as np

# Objective function: f(w, x, y, z) = sin(w) + cos(x) + y^2 - z
def objective_function(inputs):
    print(inputs)
    w = inputs[:, 0]  # Fixed context variable
    x = inputs[:, 1]  # Controlled variable
    y = inputs[:, 2]  # Controlled variable
    z = inputs[:, 3]  # Fixed context variable
    print("123 - ", (np.sin(w) + np.cos(x) + y**2 - z).reshape(-1, 1))
    return (np.sin(w) + np.cos(x) + y**2 - z).reshape(-1, 1)

# %%
import GPyOpt
import numpy as np

# Define the domain for all variables
domain = [
    {'name': 'w', 'type': 'continuous', 'domain': (-np.pi, np.pi), 'source': 'cfg'},
    {'name': 'x', 'type': 'continuous', 'domain': (-np.pi, np.pi), 'source': 'cfg'},
    {'name': 'y', 'type': 'continuous', 'domain': (-1.0, 1.0), 'source': 'cfg'},
    {'name': 'z', 'type': 'continuous', 'domain': (-1.0, 1.0), 'source': 'cfg'}
]

# Fixed context values for w and z
context = {'w': np.pi / 4, 'z': -0.5}

# Initialize the optimizer
optimizer = GPyOpt.methods.BayesianOptimization(
    f=objective_function,
    domain=domain,
    initial_design_numdata=1,
    model_type='GP',
    acquisition_type='EI',
    exact_feval=True,
    maximize=False,
)


optimizer.run_optimization(max_iter=1, context=context)

print(f"Fixed context variables: {context}")
print(f"Optimized variables: x = {optimizer.x_opt[0]}, y = {optimizer.x_opt[1]}")
print(f"Optimal objective value: {optimizer.fx_opt}")
# Out:
# [[ 0.41326949 -1.32868479 -0.83287793  0.53687515]]
# 123 -  [[0.79816932]]
# [[ 0.78539816  0.74834324  0.0338794  -0.5       ]]
# 123 -  [[1.94107177]]
# Fixed context variables: {'w': 0.7853981633974483, 'z': -0.5}
# Optimized variables: x = 0.41326949416200254, y = -1.3286847887176483
# Optimal objective value: 0.798169319776804

# %%
optimizer.get_evaluations()
# Out:
# (array([[ 0.41326949, -1.32868479, -0.83287793,  0.53687515],
#         [ 0.78539816,  0.74834324,  0.0338794 , -0.5       ]]),
#  array([[0.79816932],
#         [1.94107177]]))
