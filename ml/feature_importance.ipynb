# %%
from feature_importance import shap_feature_importance, permutation_feature_importance, gradient_boosting_feature_importance, random_forest_feature_importance, lasso_feature_importance
import pandas as pd

# %%
X = pd.read_csv('../artefacts_copy/BO_initial_X', header=None)
X.columns = ['feature_' + str(i) for i in range(X.shape[1])]
X = X.iloc[:, :-1]

y = pd.read_csv('../artefacts_copy/BO_initial_Y', header=None)
y.columns = ['target']

# %%
X.head()
# Out:
#    feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0      115.0       13.0      368.0        4.0      114.0       13.0
# 1      122.0       17.0      430.0        4.0       88.0       14.0
# 2       71.0       15.0      490.0        4.0      109.0       12.0
# 3      103.0       18.0      372.0        5.0       65.0       18.0
# 4       73.0       13.0      510.0        5.0       73.0       13.0
#
#    feature_6  feature_7  feature_8  feature_9  ...  feature_307  feature_308  \
# 0      588.0        3.0        7.0        1.0  ...         16.0         54.0
# 1      548.0        2.0        7.0        5.0  ...         22.0         52.0
# 2      564.0        3.0       12.0        2.0  ...         14.0         44.0
# 3      572.0        3.0       10.0        3.0  ...         18.0         83.0
# 4      514.0        4.0        9.0        5.0  ...         29.0         54.0
#
#    feature_309  feature_310  feature_311  feature_312  feature_313  \
# 0         19.0       8833.0         71.0         14.0       2319.0
# 1         19.0       7904.0         73.0         21.0       2033.0
# 2         31.0       6002.0         74.0         30.0       2139.0
# 3         17.0       5362.0         45.0         21.0       2219.0
# 4         15.0       7964.0         62.0         24.0       2977.0
#
#    feature_314  feature_315  feature_316
# 0       2807.0          4.0         68.0
# 1       3053.0          4.0         44.0
# 2       2346.0          1.0         66.0
# 3       2035.0          1.0         53.0
# 4       2032.0          4.0         55.0
#
# [5 rows x 317 columns]

# %%
y.head()
# Out:
#     target
# 0  436.075
# 1  463.300
# 2  463.250
# 3  473.025
# 4  457.525

# %%
shap_df = shap_feature_importance(X, y)
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.

# %%
shap_df.reset_index(inplace=True)
shap_df.head(50)
# Out:
#     index      Feature  SHAP Importance
# 0     217  feature_217         0.992189
# 1     244  feature_244         0.554561
# 2      52   feature_52         0.516920
# 3     238  feature_238         0.513772
# 4     241  feature_241         0.491422
# 5      64   feature_64         0.387225
# 6     246  feature_246         0.287219
# 7     168  feature_168         0.266367
# 8      16   feature_16         0.252109
# 9     171  feature_171         0.247542
# 10    102  feature_102         0.224161
# 11    172  feature_172         0.218559
# 12    186  feature_186         0.210417
# 13     88   feature_88         0.191149
# 14     62   feature_62         0.176055
# 15     42   feature_42         0.175454
# 16    218  feature_218         0.166250
# 17     78   feature_78         0.165808
# 18     17   feature_17         0.163122
# 19      8    feature_8         0.160241
# 20    290  feature_290         0.159327
# 21     21   feature_21         0.158768
# 22    189  feature_189         0.156539
# 23    235  feature_235         0.155399
# 24    173  feature_173         0.149037
# 25     82   feature_82         0.146524
# 26     58   feature_58         0.144541
# 27     74   feature_74         0.139103
# 28     28   feature_28         0.139038
# 29    140  feature_140         0.137443
# 30     38   feature_38         0.137386
# 31    215  feature_215         0.135764
# 32    144  feature_144         0.135412
# 33     20   feature_20         0.134624
# 34    177  feature_177         0.130725
# 35    247  feature_247         0.128585
# 36    294  feature_294         0.127527
# 37    245  feature_245         0.124026
# 38    222  feature_222         0.120724
# 39    291  feature_291         0.119000
# 40    261  feature_261         0.118973
# 41      1    feature_1         0.118837
# 42    143  feature_143         0.117877
# 43    307  feature_307         0.117811
# 44     96   feature_96         0.114850
# 45     12   feature_12         0.113428
# 46    146  feature_146         0.112698
# 47    263  feature_263         0.111837
# 48     26   feature_26         0.110726
# 49    266  feature_266         0.107964

# %%
rf_df = random_forest_feature_importance(X, y)
rf_df.reset_index(inplace=True)
rf_df.head(50)
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#     index      Feature  RF Importance
# 0     217  feature_217       0.021582
# 1     238  feature_238       0.018967
# 2      26   feature_26       0.017363
# 3     244  feature_244       0.014657
# 4     241  feature_241       0.014268
# 5     171  feature_171       0.012435
# 6     249  feature_249       0.011490
# 7      52   feature_52       0.011013
# 8     186  feature_186       0.010958
# 9     245  feature_245       0.010496
# 10    313  feature_313       0.010350
# 11    261  feature_261       0.009939
# 12     64   feature_64       0.009905
# 13    168  feature_168       0.009588
# 14    218  feature_218       0.008406
# 15    102  feature_102       0.008242
# 16    294  feature_294       0.007954
# 17    290  feature_290       0.007782
# 18    246  feature_246       0.007756
# 19     88   feature_88       0.007663
# 20    172  feature_172       0.007607
# 21     16   feature_16       0.007390
# 22    235  feature_235       0.007238
# 23    173  feature_173       0.007145
# 24    298  feature_298       0.006622
# 25     18   feature_18       0.006553
# 26      8    feature_8       0.006530
# 27    142  feature_142       0.006378
# 28     82   feature_82       0.006337
# 29     32   feature_32       0.006077
# 30    111  feature_111       0.005892
# 31     28   feature_28       0.005754
# 32     78   feature_78       0.005642
# 33    266  feature_266       0.005616
# 34    256  feature_256       0.005583
# 35     38   feature_38       0.005427
# 36    260  feature_260       0.005381
# 37    222  feature_222       0.005375
# 38     21   feature_21       0.005356
# 39     62   feature_62       0.005305
# 40    311  feature_311       0.005286
# 41     17   feature_17       0.005232
# 42     22   feature_22       0.005196
# 43    146  feature_146       0.005193
# 44     70   feature_70       0.005190
# 45      1    feature_1       0.005180
# 46    161  feature_161       0.005136
# 47    144  feature_144       0.005127
# 48     20   feature_20       0.004920
# 49    143  feature_143       0.004891

# %%
lasso_df = lasso_feature_importance(X, y)
lasso_df.reset_index(inplace=True)
lasso_df.head(50)
# Out:
#     index      Feature  Lasso Coefficient
# 0     263  feature_263          18.745284
# 1      35   feature_35           8.403957
# 2      58   feature_58           7.958915
# 3     129  feature_129           5.924896
# 4      71   feature_71           5.019212
# 5     136  feature_136           4.486217
# 6      36   feature_36           4.311306
# 7     183  feature_183           4.215246
# 8     127  feature_127           3.772522
# 9       3    feature_3           3.723804
# 10     45   feature_45           3.653216
# 11    251  feature_251           3.439674
# 12      7    feature_7           3.406017
# 13    205  feature_205           3.026495
# 14    167  feature_167           3.007411
# 15    145  feature_145           2.955414
# 16    221  feature_221           2.954100
# 17    212  feature_212           2.920503
# 18    163  feature_163           2.897533
# 19    229  feature_229           2.819854
# 20    152  feature_152           2.697243
# 21      1    feature_1           2.654817
# 22    268  feature_268           2.653513
# 23    117  feature_117           2.651561
# 24     41   feature_41           2.611938
# 25    202  feature_202           2.472907
# 26    133  feature_133           2.453294
# 27     15   feature_15           2.414562
# 28    288  feature_288           2.399182
# 29    297  feature_297           2.394962
# 30    273  feature_273           2.349041
# 31    132  feature_132           2.290971
# 32    199  feature_199           2.252495
# 33    112  feature_112           2.230901
# 34    282  feature_282           2.192603
# 35     30   feature_30           2.169617
# 36     11   feature_11           2.159713
# 37    303  feature_303           2.158851
# 38    175  feature_175           2.133405
# 39     54   feature_54           2.114538
# 40    120  feature_120           2.084698
# 41    147  feature_147           2.064896
# 42    227  feature_227           1.979675
# 43     56   feature_56           1.941464
# 44    153  feature_153           1.905674
# 45    301  feature_301           1.892408
# 46    272  feature_272           1.886493
# 47    220  feature_220           1.885536
# 48     46   feature_46           1.884405
# 49     53   feature_53           1.799315

# %%
permutation_df = permutation_feature_importance(X, y)
permutation_df.reset_index(inplace=True)
permutation_df.head(50)
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#     index      Feature  Permutation Importance
# 0     217  feature_217                0.059566
# 1     244  feature_244                0.032674
# 2     241  feature_241                0.029825
# 3     238  feature_238                0.029118
# 4      52   feature_52                0.027743
# 5      64   feature_64                0.020458
# 6     171  feature_171                0.015999
# 7     168  feature_168                0.015775
# 8     246  feature_246                0.013796
# 9     102  feature_102                0.012830
# 10     16   feature_16                0.011870
# 11     26   feature_26                0.011855
# 12    186  feature_186                0.011105
# 13    173  feature_173                0.010332
# 14    172  feature_172                0.009993
# 15     21   feature_21                0.009113
# 16      8    feature_8                0.008903
# 17     78   feature_78                0.008821
# 18     88   feature_88                0.008783
# 19    290  feature_290                0.008429
# 20     62   feature_62                0.008339
# 21    294  feature_294                0.008273
# 22    261  feature_261                0.007925
# 23    245  feature_245                0.007344
# 24    218  feature_218                0.007096
# 25     28   feature_28                0.006979
# 26    249  feature_249                0.006904
# 27     42   feature_42                0.006834
# 28    291  feature_291                0.006680
# 29     58   feature_58                0.006432
# 30    247  feature_247                0.006368
# 31      1    feature_1                0.006356
# 32     38   feature_38                0.006286
# 33    235  feature_235                0.006194
# 34    146  feature_146                0.006108
# 35    307  feature_307                0.006084
# 36    222  feature_222                0.006070
# 37     20   feature_20                0.006002
# 38     74   feature_74                0.005959
# 39     17   feature_17                0.005872
# 40    144  feature_144                0.005705
# 41    143  feature_143                0.005663
# 42     32   feature_32                0.005643
# 43    256  feature_256                0.005607
# 44     82   feature_82                0.005546
# 45    314  feature_314                0.005530
# 46     12   feature_12                0.005523
# 47     84   feature_84                0.005459
# 48    254  feature_254                0.005433
# 49    263  feature_263                0.005385

# %%
gb_df = gradient_boosting_feature_importance(X, y)
gb_df.reset_index(inplace=True)
gb_df.head(50)
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#     index      Feature  GB Importance
# 0      26   feature_26       0.036000
# 1     244  feature_244       0.035035
# 2     217  feature_217       0.030132
# 3      52   feature_52       0.027905
# 4     292  feature_292       0.023730
# 5     238  feature_238       0.023615
# 6     241  feature_241       0.023591
# 7     168  feature_168       0.023539
# 8     210  feature_210       0.019465
# 9     158  feature_158       0.019146
# 10     38   feature_38       0.019126
# 11    291  feature_291       0.018160
# 12     64   feature_64       0.016398
# 13    172  feature_172       0.015753
# 14     88   feature_88       0.014512
# 15     74   feature_74       0.013911
# 16    298  feature_298       0.013590
# 17     16   feature_16       0.013426
# 18    195  feature_195       0.012708
# 19     42   feature_42       0.012524
# 20     62   feature_62       0.011392
# 21    290  feature_290       0.011226
# 22     50   feature_50       0.011004
# 23    263  feature_263       0.010898
# 24    311  feature_311       0.010492
# 25    144  feature_144       0.010287
# 26     12   feature_12       0.010031
# 27      1    feature_1       0.009416
# 28    314  feature_314       0.009396
# 29    313  feature_313       0.009080
# 30    255  feature_255       0.008978
# 31    142  feature_142       0.008799
# 32    218  feature_218       0.008643
# 33    170  feature_170       0.008517
# 34    215  feature_215       0.008199
# 35      0    feature_0       0.007914
# 36    186  feature_186       0.007805
# 37     57   feature_57       0.007442
# 38    247  feature_247       0.007284
# 39    141  feature_141       0.007099
# 40    165  feature_165       0.007045
# 41    143  feature_143       0.006863
# 42     28   feature_28       0.006831
# 43    200  feature_200       0.006787
# 44     97   feature_97       0.006764
# 45     21   feature_21       0.006724
# 46    102  feature_102       0.006569
# 47     82   feature_82       0.006501
# 48    146  feature_146       0.006426
# 49      8    feature_8       0.006337

# %%
from SALib import ProblemSpec
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

model = RandomForestRegressor()
model.fit(X, y)

problem = {
    'num_vars': X.shape[1],
    'names': X.columns.tolist(),
    'bounds': [[X[col].min(), X[col].max()] for col in X.columns]
}

sp = ProblemSpec(problem)
sp.sample_saltelli(1024)

sp.set_results(model.predict(sp.samples))
sp.analyze_sobol()
sobol_df = pd.DataFrame({
        'Feature': problem['names'],
        'ST': sp.analysis['ST']
    }).sort_values(by='ST', ascending=False)
sobol_df.reset_index(inplace=True)
sobol_df.head(50)
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#     index      Feature        ST
# 0     217  feature_217  0.139393
# 1      26   feature_26  0.134700
# 2     238  feature_238  0.073455
# 3     244  feature_244  0.056733
# 4     241  feature_241  0.051682
# 5      52   feature_52  0.039200
# 6     102  feature_102  0.029057
# 7     172  feature_172  0.023318
# 8     290  feature_290  0.019875
# 9      21   feature_21  0.018924
# 10     12   feature_12  0.018887
# 11     64   feature_64  0.018082
# 12     88   feature_88  0.016429
# 13    298  feature_298  0.013654
# 14    140  feature_140  0.013256
# 15    307  feature_307  0.012732
# 16    246  feature_246  0.012719
# 17     97   feature_97  0.012572
# 18    124  feature_124  0.012108
# 19    222  feature_222  0.011790
# 20      6    feature_6  0.011243
# 21    187  feature_187  0.011197
# 22     78   feature_78  0.011169
# 23    256  feature_256  0.011153
# 24    259  feature_259  0.010891
# 25    170  feature_170  0.010470
# 26    249  feature_249  0.009949
# 27    260  feature_260  0.009003
# 28    186  feature_186  0.009000
# 29     17   feature_17  0.008990
# 30    192  feature_192  0.008982
# 31    177  feature_177  0.008872
# 32      1    feature_1  0.008869
# 33    161  feature_161  0.008362
# 34    245  feature_245  0.008266
# 35    111  feature_111  0.008150
# 36     20   feature_20  0.007937
# 37    168  feature_168  0.007913
# 38    300  feature_300  0.007824
# 39    255  feature_255  0.007501
# 40    294  feature_294  0.007381
# 41     22   feature_22  0.007333
# 42    155  feature_155  0.007218
# 43     56   feature_56  0.007117
# 44    247  feature_247  0.007082
# 45    146  feature_146  0.007044
# 46    108  feature_108  0.007035
# 47     82   feature_82  0.006952
# 48    218  feature_218  0.006422
# 49     10   feature_10  0.006416

# %%
from sklearn.decomposition import PCA
import numpy as np

pca = PCA(n_components=15)
X_pca = pca.fit_transform(X, y)

loadings = pd.DataFrame(
        np.abs(pca.components_),
        columns=X.columns
    )

explained_variance = pca.explained_variance_ratio_
weighted_loadings = loadings.multiply(explained_variance, axis=0)
importance_scores = weighted_loadings.sum(axis=0).sort_values(ascending=False)

results = pd.DataFrame({
    'Feature': importance_scores.index,
    'Importance': importance_scores.values
}).reset_index()

results.head(50)
# Out:
#     index      Feature  Importance
# 0       0  feature_178    0.484752
# 1       1  feature_102    0.451764
# 2       2  feature_254    0.434659
# 3       3   feature_26    0.420365
# 4       4  feature_158    0.007022
# 5       5  feature_234    0.005975
# 6       6   feature_82    0.005934
# 7       7  feature_310    0.005088
# 8       8  feature_170    0.003582
# 9       9   feature_94    0.003463
# 10     10  feature_260    0.003417
# 11     11   feature_18    0.003054
# 12     12   feature_32    0.002929
# 13     13  feature_109    0.002928
# 14     14  feature_246    0.002437
# 15     15  feature_108    0.002101
# 16     16  feature_185    0.001899
# 17     17  feature_313    0.001840
# 18     18  feature_161    0.001833
# 19     19  feature_261    0.001731
# 20     20  feature_237    0.001709
# 21     21  feature_184    0.001643
# 22     22  feature_162    0.001576
# 23     23   feature_33    0.001534
# 24     24   feature_86    0.001533
# 25     25  feature_314    0.001492
# 26     26  feature_146    0.001353
# 27     27  feature_298    0.000788
# 28     28  feature_238    0.000785
# 29     29  feature_249    0.000776
# 30     30  feature_174    0.000759
# 31     31   feature_85    0.000719
# 32     32  feature_169    0.000656
# 33     33   feature_17    0.000653
# 34     34   feature_22    0.000618
# 35     35  feature_110    0.000564
# 36     36   feature_70    0.000544
# 37     37  feature_173    0.000506
# 38     38  feature_250    0.000498
# 39     39  feature_142    0.000487
# 40     40   feature_66    0.000478
# 41     41   feature_97    0.000476
# 42     42   feature_98    0.000473
# 43     43   feature_34    0.000465
# 44     44   feature_21    0.000463
# 45     45  feature_294    0.000450
# 46     46   feature_93    0.000442
# 47     47  feature_245    0.000413
# 48     48  feature_186    0.000402
# 49     49  feature_218    0.000364

# %%
explained_variance
# Out:
# array([0.2852511 , 0.24386299, 0.23794818, 0.22053821, 0.00144566,
#        0.00137519, 0.00131533, 0.00125978, 0.00069325, 0.00067042,
#        0.0005999 , 0.00057587, 0.00039721, 0.0003695 , 0.00034301])
