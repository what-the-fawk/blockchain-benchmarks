# %%
from feature_importance import shap_feature_importance, permutation_feature_importance, gradient_boosting_feature_importance, random_forest_feature_importance, lasso_feature_importance
import pandas as pd

# %%
X = pd.read_csv('../artefacts_copy/BO_initial_X', header=None)
X.columns = ['feature_' + str(i) for i in range(X.shape[1])]
X = X.iloc[:, :-1]

y = pd.read_csv('../artefacts_copy/BO_initial_Y', header=None)
y.columns = ['target']

# %%
X.head()
# Out:
#    feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0      115.0       13.0      368.0        4.0      114.0       13.0
# 1      122.0       17.0      430.0        4.0       88.0       14.0
# 2       71.0       15.0      490.0        4.0      109.0       12.0
# 3      103.0       18.0      372.0        5.0       65.0       18.0
# 4       73.0       13.0      510.0        5.0       73.0       13.0
#
#    feature_6  feature_7  feature_8  feature_9  ...  feature_307  feature_308  \
# 0      588.0        3.0        7.0        1.0  ...         16.0         54.0
# 1      548.0        2.0        7.0        5.0  ...         22.0         52.0
# 2      564.0        3.0       12.0        2.0  ...         14.0         44.0
# 3      572.0        3.0       10.0        3.0  ...         18.0         83.0
# 4      514.0        4.0        9.0        5.0  ...         29.0         54.0
#
#    feature_309  feature_310  feature_311  feature_312  feature_313  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
X = StandardScaler().fit_transform(X)
X = pd.DataFrame(X, columns=['feature_' + str(i) for i in range(X.shape[1])])
X.head()
# Out:
#    feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0   1.237156   0.166558  -1.555173   0.857520   1.229089   0.141483
# 1   1.638766   1.368752  -0.881922   0.857520  -0.270968   0.440169
# 2  -1.287247   0.767655  -0.230390   0.857520   0.940616  -0.157203
# 3   0.548683   1.669300  -1.511737   1.459648  -1.597940   1.634915
# 4  -1.172501   0.166558  -0.013212   1.459648  -1.136385   0.141483
#
#    feature_6  feature_7  feature_8  feature_9  ...  feature_307  feature_308  \
# 0   0.801034   0.313755  -1.564708  -0.862584  ...    -1.283951    -0.809775
# 1   0.358243  -0.275447  -1.564708   1.459205  ...    -0.114089    -0.976372
# 2   0.535359   0.313755  -0.158473  -0.282137  ...    -1.673905    -1.642760
# 3   0.623917   0.313755  -0.720967   0.298310  ...    -0.893997     1.605881
# 4  -0.018130   0.902957  -1.002214   1.459205  ...     1.250751    -0.809775
#
#    feature_309  feature_310  feature_311  feature_312  feature_313  \
# ...

# %%
y.head()
# Out:
#     target
# 0  436.075
# 1  463.300
# 2  463.250
# 3  473.025
# 4  457.525

# %%
shap_df = shap_feature_importance(X, y)
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.

# %%
shap_df.reset_index(inplace=True)
shap_df.head(50)
# Out:
#     index      Feature  SHAP Importance
# 0     217  feature_217         0.993679
# 1     244  feature_244         0.555256
# 2      52   feature_52         0.515959
# 3     238  feature_238         0.511418
# 4     241  feature_241         0.490431
# 5      64   feature_64         0.388609
# 6     246  feature_246         0.286003
# 7     168  feature_168         0.266423
# 8      16   feature_16         0.250118
# 9     171  feature_171         0.248027
# 10    102  feature_102         0.222873
# 11    172  feature_172         0.219168
# 12    186  feature_186         0.212706
# 13     88   feature_88         0.191690
# 14     62   feature_62         0.177330
# 15     42   feature_42         0.175753
# 16    218  feature_218         0.166458
# 17     78   feature_78         0.166050
# 18     17   feature_17         0.161242
# 19      8    feature_8         0.161070
# 20    290  feature_290         0.159251
# 21     21   feature_21         0.158762
# ...

# %%
# rf_df = random_forest_feature_importance(X, y)
# rf_df.reset_index(inplace=True)
# rf_df.head(50)

# %%
# lasso_df = lasso_feature_importance(X, y)
# lasso_df.reset_index(inplace=True)
# lasso_df.head(50)

# %%
# permutation_df = permutation_feature_importance(X, y)
# permutation_df.reset_index(inplace=True)
# permutation_df.head(50)

# %%
# gb_df = gradient_boosting_feature_importance(X, y)
# gb_df.reset_index(inplace=True)
# gb_df.head(50)

# %%
from SALib import ProblemSpec
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

model = RandomForestRegressor()
model.fit(X, y)

problem = {
    'num_vars': X.shape[1],
    'names': X.columns.tolist(),
    'bounds': [[X[col].min(), X[col].max()] for col in X.columns]
}

sp = ProblemSpec(problem)
sp.sample_saltelli(1)

sp.set_results(model.predict(sp.samples))
sp.analyze_sobol()
sobol_df = pd.DataFrame({
        'Feature': problem['names'],
        'ST': sp.analysis['ST']
    }).sort_values(by='ST', ascending=False)
sobol_df.reset_index(inplace=True)
sobol_df.head(50)
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
#         Convergence properties of the Sobol' sequence is only valid if
#         `N` (1) is equal to `2^n`.
#
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#     index      Feature        ST
# 0     217  feature_217  1.888338
# 1     238  feature_238  0.441362
# 2     244  feature_244  0.309615
# 3      57   feature_57  0.152367
# 4     298  feature_298  0.123787
# 5      62   feature_62  0.091399
# 6     291  feature_291  0.085245
# 7     246  feature_246  0.055766
# 8     263  feature_263  0.054285
# 9     140  feature_140  0.053086
# 10    168  feature_168  0.050145
# 11    308  feature_308  0.042725
# 12      9    feature_9  0.031361
# 13     16   feature_16  0.029055
# 14    146  feature_146  0.024887
# 15    142  feature_142  0.023677
# 16    307  feature_307  0.023428
# ...

# %%
from sklearn.decomposition import PCA
import numpy as np

pca = PCA(n_components=15)
X_pca = pca.fit_transform(X, y)

loadings = pd.DataFrame(
        np.abs(pca.components_),
        columns=X.columns
    )

explained_variance = pca.explained_variance_ratio_
weighted_loadings = loadings.multiply(explained_variance, axis=0)
importance_scores = weighted_loadings.sum(axis=0).sort_values(ascending=False)

results = pd.DataFrame({
    'Feature': importance_scores.index,
    'Importance': importance_scores.values
}).reset_index()

results.head(50)
# Out:
#     index      Feature  Importance
# 0       0  feature_274    0.010479
# 1       1   feature_58    0.010209
# 2       2   feature_69    0.010041
# 3       3  feature_190    0.010000
# 4       4  feature_140    0.009924
# 5       5  feature_307    0.009881
# 6       6  feature_242    0.009876
# 7       7   feature_96    0.009726
# 8       8  feature_145    0.009600
# 9       9  feature_207    0.009471
# 10     10  feature_231    0.009451
# 11     11  feature_171    0.009373
# 12     12  feature_251    0.009261
# 13     13    feature_6    0.009259
# 14     14  feature_158    0.009197
# 15     15  feature_121    0.009186
# 16     16  feature_308    0.009177
# 17     17  feature_226    0.009161
# 18     18   feature_48    0.009160
# 19     19   feature_90    0.009088
# 20     20  feature_222    0.009022
# 21     21   feature_92    0.009016
# 22     22  feature_102    0.008988
# 23     23  feature_277    0.008959
# 24     24  feature_296    0.008957
# 25     25  feature_187    0.008956
# ...

# %%
explained_variance
# Out:
# array([0.0122023 , 0.01179666, 0.01167945, 0.01139808, 0.01119429,
#        0.01103056, 0.0108868 , 0.01067459, 0.01048303, 0.01041764,
#        0.01038121, 0.01017246, 0.00997811, 0.00990357, 0.00982467])

# %%
from sklearn.decomposition import PCA

# %%
shap_df = shap_feature_importance(X, y).head(15)
shap_df.index.to_list()
# Out:
# [217, 244, 52, 238, 241, 64, 246, 168, 16, 171, 102, 172, 186, 88, 62]

# %%
import GPyOpt
from domain import read_configs, controllable_params, transform_domain
from globals import set_model_type

set_model_type('BO')

read_configs([
        "../networks/configtx/configtx.yaml",
        "../networks/compose/docker/peercfg-org1/core.yaml",
        "../networks/compose/docker/peercfg-org2/core.yaml",
        "../networks/compose/docker/peercfg-org3/core.yaml",
        "../networks/compose/docker/peercfg-org4/core.yaml",
        # "../networks/compose/docker/ordcfg/orderer.yaml",
])

print(controllable_params)
print(len(controllable_params))
# Out:
# Setting model type to: BO
# ...

# %%
len(controllable_params)
# Out:
# 317

# %%
def fit(X):
    print("FIT")
    raise Exception("BO fit")
    return 1.0

opt = GPyOpt.methods.BayesianOptimization(
            f=fit,
            domain=transform_domain(controllable_params),
            acquisition_type='EI',
            maximize=True,
            initial_design_numdata=0,
            normalize_Y=True,
            num_cores=6,
            X=X.to_numpy(),
            Y=y.to_numpy(),
        )

# opt._update_model()
# opt.run_optimization(max_iter=1)

# %%
# opt.model.predict(np.ndarray([0]))
# opt.acquisition_optimizer.model.predict(np.ndarray([0]))
opt._update_model()

# %%
from SALib.sample import saltelli
from SALib.analyze import sobol
import numpy as np
import time

from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor

model = RandomForestRegressor(n_estimators=200, random_state=13)
model.fit(X, y)

problem = {
    'num_vars': len(controllable_params),
    'names': [item['name'] for item in controllable_params],
    'bounds': [item['bounds'] for item in controllable_params]
}

start_time = time.time()
param_values = saltelli.sample(problem, 1024, calc_second_order=True)
# sp = ProblemSpec(problem)
# sp.sample_saltelli(256)
print("Generated samples in ", time.time() - start_time, "seconds")
Y_predicted = np.array([])

print("Sample number: ", param_values.shape)
# opt.
# raise RuntimeError('Stop here 1')
# Out:
# Generated samples in  57.10919237136841 seconds
# Sample number:  (651264, 317)

# %%
from tqdm import tqdm

# for i, x in tqdm(enumerate(param_values)):
#     # print(x)
#     # print(i)
#     prediction = opt.model.predict(x)
#     # print(prediction)
#     Y_predicted = np.append(Y_predicted, prediction[1])
    # raise RuntimeError('Stop here')
prediction = model.predict(param_values)
prediction
# Out:
# array([467.229625, 467.477625, 467.229625, ..., 471.424125, 471.369   ,
#        471.459875])

# %%
min(prediction), max(prediction), np.mean(prediction), np.std(prediction)
# Out:
# (448.2336250000002, 475.33149999999995, 467.3781309415229, 2.5713738306073903)

# %%
len(prediction)
# Out:
# 651264

# %%
Y_predicted = []
for item in prediction:
    Y_predicted.append(item)
len(Y_predicted)
# Out:
# 651264

# %%
y.shape
# Out:
# (323, 1)

# %%
# model = RandomForestRegressor()
# X_rand = pd.DataFrame(np.random.rand(100, 317), columns=[f'feature_{i}' for i in range(317)])
# y_rand = pd.Series(np.random.rand(100))
# model.fit(X_rand, y_rand)

# print(sp.samples)

Si = sobol.analyze(problem, prediction, calc_second_order=True, print_to_console=True)
print(Si['S1'])
print(Si['ST'])
sobol_df = pd.DataFrame({
        'Feature': problem['names'],
        'ST': Si['ST']
        
    }).sort_values(by='ST', ascending=False)
sobol_df.reset_index(inplace=True)
sobol_df.head(50)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[22], line 8
#       1 # model = RandomForestRegressor()
#       2 # X_rand = pd.DataFrame(np.random.rand(100, 317), columns=[f'feature_{i}' for i in range(317)])
#       3 # y_rand = pd.Series(np.random.rand(100))
#       4 # model.fit(X_rand, y_rand)
#       5
#       6 # print(sp.samples)
# ----> 8 Si = sobol.analyze(problem, prediction, calc_second_order=False, print_to_console=True)
#       9 print(Si['S1'])
#      10 print(Si['ST'])
#
# File ~/.local/lib/python3.10/site-packages/SALib/analyze/sobol.py:128, in analyze(problem, Y, calc_second_order, num_resamples, conf_level, print_to_console, parallel, n_processors, keep_resamples, seed)
#     126     N = int(Y.size / (D + 2))
#     127 else:
# --> 128     raise RuntimeError(
#     129         """
#     130     Incorrect number of samples in model output file.
# ...

# %%
# problem = {
#     'num_vars': 3,
#     'names': ['x1', 'x2', 'x3'],
#     'bounds': [[0, 1], [0, 1], [0, 1]]
# }

# start_time = time.time()
# param_values = saltelli.sample(problem, 128)
# print("Generated samples in ", time.time() - start_time, "seconds")
# Y_predicted = np.zeros([param_values.shape[0]])

# print(param_values)

# opt = GPyOpt.methods.BayesianOptimization(
#             f=fit,
#             domain=transform_domain(controllable_params)[0:3],
#             acquisition_type='EI',
#             maximize=True,
#             initial_design_numdata=0,
#             num_cores=6
#         )

# %%
# DR TECHNIQUES

# variable selection (shap, pca, sa) -> DONE
# REMBO
# SIR
# VAE

# %%
# ACQUISITIONS

# %%
from typing import List

# %%
def check_validity(AF:str, DR: str, d_effective: int, n_epochs: int):
    if AF not in ['EI', 'DYCORS', 'UCB', 'MES']:
        raise ValueError("Invalid acquisition function. Choose from 'EI', 'PI', or 'UCB'")
    
    if DR not in ['shap', 'pca', 'sa', 'rembo', 'sir', 'vae']:
        raise ValueError("Invalid dimensionality reduction method. Choose from 'shap', 'pca', 'sa', 'rembo', 'sir', or 'vae'")
    
    if d_effective <= 0:
        raise ValueError("d_effective must be a positive integer.")
    
    if n_epochs <= 0:
        raise ValueError("n_epochs must be a positive integer.")
    
    return True

class BayesianOpt:
    def __init__(self,
                X: pd.DataFrame, 
                y: pd.Series, 
                AF: str, 
                DR: str, 
                d_effective: int, 
                n_epochs: int,
                domain: List
                ):
        
        check_validity(AF, DR, d_effective, n_epochs)
        
        # match DR:

        self.domain = domain
        if DR in ['shap', 'pca', 'sa']:
            self.context = []
        
        self.d_effective = d_effective


        return None
    
    def transform(X: np.ndarray, DR: str) -> np.ndarray: # reconstruct
        if DR in ['shap', 'pca', 'sa']:
            # do nothing
            return X
        
        if DR == 'rembo':
            # apply rembo
            pass
        elif DR == 'sir':
            # apply sir
            pass
        elif DR == 'vae':
            # apply vae
            pass
        else:
            raise ValueError("Invalid dimensionality reduction method")

        pass

    

    def run_model(self):
        pass
